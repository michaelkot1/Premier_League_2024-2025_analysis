# %%
from IPython.display import IFrame

IFrame(
    src="https://public.tableau.com/views/PremierLeagueDataInsight/Expected_90_vs_Goals?:showVizHome=no",
    width=1100,
    height=800
)
# Out:
#         <iframe
#             width="1100"
#             height="800"
#             src="https://public.tableau.com/views/PremierLeagueDataInsight/Expected_90_vs_Goals?:showVizHome=no"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
